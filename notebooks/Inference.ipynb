# %% [markdown]
# ## Setting up for inference

# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/MasterCourse/Flowers Recognizer
# Out:
# /content/drive/My Drive/MasterCourse/Flowers Recognizer

# %%
version = 1
img_path = 'test images'
model_path = f'models/flowers_recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# ## Inference 1

# %% [markdown]
# Target : Dandelion

# %%
img = Image.open(f'{img_path}/test01.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x87>

# %%
model.predict(f'{img_path}/test01.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('dandelion',
#  tensor(4),
#  tensor([4.2471e-05, 1.0858e-04, 4.9142e-04, 1.2492e-04, 9.9728e-01, 1.1834e-05,
#          5.4582e-05, 4.1614e-06, 1.8544e-03, 3.1317e-05]))

# %% [markdown]
# ## Inference 2

# %% [markdown]
# Target : Iris

# %%
img = Image.open(f'{img_path}/test02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/test02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('iris',
#  tensor(5),
#  tensor([6.8335e-06, 1.9901e-06, 2.1672e-07, 1.6297e-07, 5.5968e-07, 9.9983e-01,
#          1.4435e-04, 9.0141e-06, 1.0020e-06, 1.1538e-06]))

# %% [markdown]
# # Inference 3

# %% [markdown]
# Target : Sunflower

# %%
img = Image.open(f'{img_path}/test03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/test03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('dandelion',
#  tensor(4),
#  tensor([1.2839e-03, 9.0518e-03, 8.3259e-04, 5.0613e-02, 4.6793e-01, 1.5231e-02,
#          1.4414e-06, 4.7310e-06, 4.5241e-01, 2.6422e-03]))

# %% [markdown]
# ## Inference 4

# %% [markdown]
# Target : Dahlia

# %%
img = Image.open(f'{img_path}/test04.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x71>

# %%
model.predict(f'{img_path}/test04.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('dahlia',
#  tensor(2),
#  tensor([2.3642e-05, 8.7402e-08, 9.9988e-01, 3.3343e-07, 1.2038e-06, 2.2077e-07,
#          2.0812e-07, 8.1751e-05, 1.4078e-07, 8.3172e-06]))
